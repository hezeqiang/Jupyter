# %% [markdown]
# ssh Cygwin environment

# %% [markdown]
# $ ssh-keygen -t rsa  # generate the ssh key in the pcsa
#
# #login the ssh point
# $ chmod 600 ~/.ssh
# $ chmod 700 ~/.ssh/id_rsa
# ssh 20M18053@login.t3.gsic.titech.ac.jp -i C:\Users\shinshi/.ssh/id_rsa -YC
#
# $ chmod 600 C:/\Users/\shinshi/.ssh
# $ chmod 700 C:/\Users/\shinshi/.ssh/id_rsa
#
#
# $ module avail
# $ module load ansys
# $ module load cuda
# $ module list
#
# #remove module
# $ module purge
