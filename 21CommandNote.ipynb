# %% [markdown]
# # Ubuntu system  commands

# %% [markdown]
# ## config default Python interptor:
#
# - fishros initialize >>>
# source /opt/ros/humble/setup.bash
# - fishros initialize <<<
#
# export PYTHON_EXECUTABLE=/usr/bin/python3
#
# - Initialize conda (for manual use) but do not auto-activate
# eval "$(/home/he/anaconda3/bin/conda shell.bash hook)"
# conda config --set auto_activate_base false

# %% [markdown]
# * cd
# * mkdir
# * pwd
# * ls
# * mkdir
# * rm
# * rm -rf dir_name
# * cp file1.txt file2.txt
# * mv file1.txt /path/to/new/location
# * touch newfile.txt
# * cat file1.txt file2.txt > combined_file.txt

# %% [markdown]
# * sudo apt install package_name
# * sudo apt-get install package_name
# * sudo apt-get update package_name
# * sudo apt-get install -y package_name
# * sudo apt-get remove -y package_name
# * sudo apt-get purge -y package_name
# * sudo apt-get upgrade
# * sudo apt-get install make gcc g++
# * cmake .
# * make

# %% [markdown]
# * source ~/.bashrc
# * vim ~/.bashrc  # vim usage I :wq
# * echo "export PATH=$PATH:/path/to/your/script" >> ~/.bashrc
# * wget http://example.com/file.zip
# * curl https://github.com
# * unzip file.zip
# * tar -xzf file.tar.gz
# * eval  "export PATH=$PATH:/path/to/bin/bash" >> ~/.bash
# * chmod +x /path/to/your/script.sh

# %% [markdown]
# * conda create -n env_name python=version_number
# * conda activate env_name
# * conda deactivate
# * conda install -c conda-forge package_name
# * conda remove -n env_name --all
# * conda env list --all
# * pip freeze > requirements.txt # make the requirements.txt file
# * pip install -r requirements.txt
