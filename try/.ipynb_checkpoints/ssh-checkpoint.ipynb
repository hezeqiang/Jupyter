# %% [markdown]
# ssh Cygwin environment

# %% [markdown]
# $ ssh-keygen -t rsa  # generate the ssh key in the pc in the directory C:\cygwin64\home\shinshi
# $ ls ~/.ssh/ -1  #check the file
# #login the ssh point
# $ chmod600 ~/.ssh
# $ chmod700 ~/.ssh/id_rsa
#
# $ ssh 20M18053@login.t3.gsic.titech.ac.jp -i ~/.ssh/id_rsa -YC
#
# C:\cygwin64\home\shinshi\.ssh
# ssh 20M18053@login.t3.gsic.titech.ac.jp -i C:/cygwin64/home/shinshi/.ssh/id_rsa -YC
