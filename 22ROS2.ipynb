# %% [markdown]
# * ros2 run package_name node_name
# * ros2 node list
# * ros2 node info /node_name
# * ros2 topic list
# * ros2 topic info /topic_name
# * ros2 service list
# * ros2 service info /service_name
# * ros2 action list
# * ros2 action info /action_name
# * ros2 param list
# * ros2 param get /param_name
# * ros2 param set /param_name value
# * ros2 param delete /param_name
# * ros2 launch package_name launch_file.launch.py

# %% [markdown]
# * printenv | grep ament
# * source install/setup.bash
# * colcon build
# * source install/setup.bash
#
# * ros2 pkg create cpp_pkg_name --build-type ament_cmake --dependencies rclcpp
# * ros2 pkg create py_pkg_name  --build-type ament_python --dependencies rclpy

# %% [markdown]
# # Robotpkg install
#
# ~ http://robotpkg.openrobots.org/debian.html
#
# export ROBOTPKG_BASE=~/robotpkg/install
# export PATH=$ROBOTPKG_BASE/sbin:$PATH
# export PKG_PATH=$ROBOTPKG_BASE
# export PYTHONPATH=$ROBOTPKG_BASE/lib/python3.10/site-packages:/opt/openrobots/lib/python3.10/site-packages:/usr/lib/python3/dist-packages:$PYTHONPATH
#
# sudo apt-get install robotpkg-pinocchio
# sudo apt-get install robotpkg-py310-pinocchio
#
#
# apt-cache search example-robot-data
# sudo apt-get install robotpkg-example-robot-data
# sudo apt-get install robotpkg-py310-example-robot-data
#
#
# ## install both lib and its python blinding
